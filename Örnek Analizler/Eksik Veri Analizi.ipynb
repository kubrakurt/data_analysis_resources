# %% [markdown]
# # 1. Eksik Veri Analizi
#
# * Veri setindeki eksikliğin yapısal bir eksiklik olup olmadığı bilinmesi gerekiyor.
# * Yapısal olması durumu, kredi kartı olmayan birisinin kresi kartı toplam harcaması NA olur.
# * Rastlantısal ise veri girişlerinde ya da aktarımında oluşan eksikliklerdir.
# * NA her zaman eksiklik olduğu anlamına gelmez.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# * Kaçar tane eksik değer var?

# %%
df.isnull().sum()
# Out:
# V1    2
# V2    3
# V3    2
# dtype: int64

# %% [markdown]
# * Boş olmayan değerlerin sayısı kaçtır?

# %%
df.notnull().sum()
# Out:
# V1    7
# V2    6
# V3    7
# dtype: int64

# %% [markdown]
# * Veri setinde toplam kaç eksik değer var?

# %%
df.isnull().sum().sum()
# Out:
# 7

# %% [markdown]
# * Eksik değer olan satırlara bakalım.
# * **any:** En az bir tane eksik değer varsa.

# %%
df[df.isnull().any(axis=1)]
# Out:
#     V1   V2    V3
# 0  1.0  7.0   NaN
# 1  3.0  NaN  12.0
# 3  NaN  8.0   6.0
# 5  1.0  NaN   7.0
# 6  NaN  NaN   NaN

# %% [markdown]
# * Eksik veri olmayan satırlara bakalım.
# * **all:** Satırda hepsi dolu.

# %%
df[df.notnull().all(axis=1)]
# Out:
#      V1    V2    V3
# 2   6.0   5.0   5.0
# 4   7.0  12.0  14.0
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# ## 1.1. Eksik Gözlemlerin Kaldırılması

# %%
df.dropna(inplace = True)
df
# Out:
#      V1    V2    V3
# 2   6.0   5.0   5.0
# 4   7.0  12.0  14.0
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# ## 1.2. Basit Değer Atama

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
columns = df.columns

for col in columns:
    df[col] = df[col].fillna(df[col].mean())
    
df
# Out:
#      V1         V2    V3
# 0   1.0   7.000000  11.0
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667  11.0
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
for col in columns:
    df[col] = df[col].fillna(0)
    
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   0.0
# 1   3.0   0.0  12.0
# 2   6.0   5.0   5.0
# 3   0.0   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   0.0   7.0
# 6   0.0   0.0   0.0
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
df = df.apply(lambda x : x.fillna(x.mean()), axis = 0)
df
# Out:
#      V1         V2    V3
# 0   1.0   7.000000  11.0
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667  11.0
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0

# %% [markdown]
# ## 2. Eksik Veri Yapısının Görselleştirilmesi

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
msno.bar(df);

# %%
msno.matrix(df);

# %%
df = sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %% [markdown]
# * orbital_period ne zaman eksikse mass değişkeni de eksik oluyor.
# * Aralarında bir ilişki olduğunu görüyoruz.
# * mass'deki eksiklerin bazıları orbital_period değişkenine bağlı olarak gerçekleşmiştir.
# * mass ve distance arasında da bağımlılık var fakat diğerleri kadar yoktur.

# %%
msno.matrix(df);

# %% [markdown]
# * Isı haritası ile bakalım.
# * Değişkenlerin birbirlerini nasıl etkilediğini görürüz.
# * 1'e ne kadar yakınsa birbirlerini o kadar çok etkilemektedirler.

# %%
msno.heatmap(df);

# %% [markdown]
# ## 1.3. Silme Yöntemleri

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# * En az bir tane eksik veri olan gözlemlerin kaldırılması.

# %%
df.dropna()
# Out:
#      V1    V2    V3
# 2   6.0   5.0   5.0
# 4   7.0  12.0  14.0
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# * Tüm gözlemlerin aynı anda NaN olması durumunda kaldırılması.

# %%
df.dropna(how = "all")
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# * En az bir NaN değer olan gözlemlerin kaldırılması.

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# * Tüm değerleri NaN olan gözlemlerin kaldırılması.

# %%
df.dropna(axis = 1, how = "all")
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
df["V4"] = np.NaN
df
# Out:
#      V1    V2    V3  V4
# 0   1.0   7.0   NaN NaN
# 1   3.0   NaN  12.0 NaN
# 2   6.0   5.0   5.0 NaN
# 3   NaN   8.0   6.0 NaN
# 4   7.0  12.0  14.0 NaN
# 5   1.0   NaN   7.0 NaN
# 6   NaN   NaN   NaN NaN
# 7   9.0   2.0   2.0 NaN
# 8  15.0   3.0  31.0 NaN

# %%
df.dropna(axis = 1, how = "all", inplace = True)
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %% [markdown]
# ## 1.4. Basit Değer Atama Yöntemleri

# %%
V1 = np.array([1,3,6,np.NaN,7,1,np.NaN,9,15])
V2 = np.array([7,np.NaN,5,8,12,np.NaN,np.NaN,2,3])
V3 = np.array([np.NaN,12,5,6,14,7,np.NaN,2,31])

df = pd.DataFrame({"V1" : V1,
                   "V2" : V2,
                   "V3" : V3})
df
# Out:
#      V1    V2    V3
# 0   1.0   7.0   NaN
# 1   3.0   NaN  12.0
# 2   6.0   5.0   5.0
# 3   NaN   8.0   6.0
# 4   7.0  12.0  14.0
# 5   1.0   NaN   7.0
# 6   NaN   NaN   NaN
# 7   9.0   2.0   2.0
# 8  15.0   3.0  31.0

# %%
df["V1"].fillna(0)
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     0.0
# 4     7.0
# 5     1.0
# 6     0.0
# 7     9.0
# 8    15.0
# Name: V1, dtype: float64

# %%
df["V1"].fillna(df["V1"].mean())
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     6.0
# 4     7.0
# 5     1.0
# 6     6.0
# 7     9.0
# 8    15.0
# Name: V1, dtype: float64

# %% [markdown]
# * Tüm değişkenlere aynı işlem yapılsın.

# %%
df.apply(lambda x : x.fillna(x.mean()), axis = 0)
# Out:
#      V1         V2    V3
# 0   1.0   7.000000  11.0
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667  11.0
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0

# %%
df.fillna(df.mean()[:])
# Out:
#      V1         V2    V3
# 0   1.0   7.000000  11.0
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667  11.0
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0

# %% [markdown]
# * Dağılımları **düzgün / simetrik / normal dağılımda** ise bunları ortalama ile doldurmak mantıklı olur.
# * Çarpıklık söz konusu ise ortalama ile doldurmak mantıklı olmaz.
# * Şimdi ilk iki değişkeni ortalama ile son değişkeni medyan ile dolduruyoruz.

# %%
df.fillna(df.mean()["V1":"V2"])
# Out:
#      V1         V2    V3
# 0   1.0   7.000000   NaN
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667   NaN
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0

# %%
df["V3"].fillna(df["V3"].median())
# Out:
# 0     7.0
# 1    12.0
# 2     5.0
# 3     6.0
# 4    14.0
# 5     7.0
# 6     7.0
# 7     2.0
# 8    31.0
# Name: V3, dtype: float64

# %%
df.where(pd.notna(df), df.mean(), axis = "columns")
# Out:
#      V1         V2    V3
# 0   1.0   7.000000  11.0
# 1   3.0   6.166667  12.0
# 2   6.0   5.000000   5.0
# 3   6.0   8.000000   6.0
# 4   7.0  12.000000  14.0
# 5   1.0   6.166667   7.0
# 6   6.0   6.166667  11.0
# 7   9.0   2.000000   2.0
# 8  15.0   3.000000  31.0
